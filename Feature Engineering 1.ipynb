# %% [markdown]
# # Python Learning Sessions: Feature Engineering

# %% [markdown]
# ## Basics

# %% [markdown]
# ### Pipelines
# Piplines are a way to combine multiple steps of preprocessing into a single step.
# Pandas has a built-in function for creating pipelines. The method can be called by a DataFrame.pipe() method. You can pass a function to the pipe() method and chain multiple transformations together by calling the pipe() method after another.
#
# SKLearn has a built-in pipeline class that sequentially applies each step of the pipeline. SKLearn also has ColumnTransformer class that can be used to combine multiple steps of preprocessing into a single step. These two classes can be used together to provide a more flexible way to combine multiple steps of preprocessing into a single step.

# %% [markdown]
# #### Pandas Pipeline
# ---

# %% [markdown]
# When applying a series of transformations to a dataframe, we usually call it like this:
#
# ```python
# df = h(df)
# df = g(df, arg1=a)
# df = func(df, arg2=b, arg3=c)
# ```
#
# Or we can nest the transformations using functions:
# ```python
# df = func(g(h(df), arg1=a), arg2=b, arg3=c)
# ```
#
# Or we can use the pipe() method to apply a series of transformations to a dataframe:
#
# ```python
# (df.pipe(h)
#    .pipe(g, arg1=a)
#    .pipe(func, arg2=b, arg3=c)
# )
# ```

# %% [markdown]
# You can define a pipeline operator as a function that takes a dataframe and returns a dataframe.

# %%
import pandas as pd
import numpy as np

link = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/taxis.csv'
df = pd.read_csv(link)
df
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 0     2.15    0.0  12.95  yellow  credit card        Lenox Hill West
# 1     0.00    0.0   9.30  yellow         cash  Upper West Side South
# 2     2.36    0.0  14.16  yellow  credit card          Alphabet City
# 3     6.15    0.0  36.95  yellow  credit card              Hudson Sq
# 4     1.10    0.0  13.40  yellow  credit card           Midtown East
# ...    ...    ...    ...     ...          ...                    ...
# 6428  1.06    0.0   6.36   green  credit card      East Harlem North
# 6429  0.00    0.0  58.80   green  credit card                Jamaica
# 6430  0.00    0.0  17.30   green         cash    Crown Heights North
# 6431  0.00    0.0   6.80   green  credit card          East New York
# 6432  3.36    0.0  20.16   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6428              Central Harlem North      Manhattan       Manhattan
# 6429  East Concourse/Concourse Village         Queens           Bronx
# 6430                    Bushwick North       Brooklyn        Brooklyn
# 6431      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6432                   Windsor Terrace       Brooklyn        Brooklyn
#
# [6433 rows x 14 columns]

# %%
def get_unique_routes(df):
    """
    Get the number of unique routes
    
    Parameters
    ----------
    df : pandas.DataFrame
        DataFrame with the taxi data

    Returns
    -------
    df : pandas.DataFrame
        DataFrame with the taxi data with the number of unique routes

    """
    df = df.groupby(by=['pickup_borough', 'dropoff_borough']).agg({
        'distance': 'mean',
        'fare': 'mean',
        'tip': 'mean',
        'tolls': 'mean',
        'payment': pd.Series.mode,
        'color': pd.Series.mode,
    })
    df.reset_index(inplace=True)
    df['route'] = df.pickup_borough + '-' + df.dropoff_borough
    df.drop(['pickup_borough', 'dropoff_borough'], axis=1, inplace=True)
    return df


def bin_distance(df, bins):
    """
    Bin the distance column

    Parameters
    ----------
    df : pandas.DataFrame
        DataFrame with the taxi data
    bins : list
        List of bins to use

    Returns
    -------
    df : pandas.DataFrame
        DataFrame with the taxi data with the distance column binned

    """
    df['distance_bin'] = pd.cut(df.distance, bins)
    df.drop(['distance'], axis=1, inplace=True)
    return df


def get_tip_toll_percentage(df):
    """
    Get the percentage of tip and tolls
    
    Parameters
    ----------
    df : pandas.DataFrame
        DataFrame with the taxi data
        
    Returns
    -------
    df : pandas.DataFrame
        DataFrame with the taxi data with the percentage of tip and tolls

    """
    df['ave_tip_percentage'] = df.tip / (df.fare)
    df['ave_toll_percentage'] = df.tolls / (df.fare)
    df.drop(['tip', 'tolls'], axis=1, inplace=True)
    return df

# %%
df.pipe(get_unique_routes)\
  .pipe(bin_distance, bins=np.arange(0, 100, 5))\
  .pipe(get_tip_toll_percentage)
# Out:
#          fare              payment   color                    route  \
# 0   14.539091          credit card   green              Bronx-Bronx
# 1   54.062500          credit card   green           Bronx-Brooklyn
# 2   29.698000          credit card   green          Bronx-Manhattan
# 3   40.157500          credit card   green             Bronx-Queens
# 4   58.124000          credit card   green           Brooklyn-Bronx
# 5   11.877589          credit card   green        Brooklyn-Brooklyn
# 6   25.096567          credit card   green       Brooklyn-Manhattan
# 7   34.842692          credit card   green          Brooklyn-Queens
# 8   24.127273  [cash, credit card]  yellow          Manhattan-Bronx
# 9   24.495098          credit card  yellow       Manhattan-Brooklyn
# 10   9.727019          credit card  yellow      Manhattan-Manhattan
# 11  34.623804          credit card  yellow         Manhattan-Queens
# 12  44.500000          credit card  yellow  Manhattan-Staten Island
# 13  45.772727          credit card  yellow             Queens-Bronx
# 14  37.018871          credit card  yellow          Queens-Brooklyn
# 15  36.923839          credit card  yellow         Queens-Manhattan
# 16  12.812178                 cash   green            Queens-Queens
#
#    distance_bin  ave_tip_percentage  ave_toll_percentage
# 0        (0, 5]            0.006586             0.008754
# 1      (10, 15]            0.000000             0.079908
# 2       (5, 10]            0.011300             0.038144
# 3      (10, 15]            0.000000             0.143435
# 4      (15, 20]            0.000000             0.099098
# 5        (0, 5]            0.052987             0.000000
# 6       (5, 10]            0.092901             0.047958
# 7      (10, 15]            0.040203             0.000000
# 8       (5, 10]            0.036963             0.010309
# 9       (5, 10]            0.138886             0.027606
# 10       (0, 5]            0.181144             0.000543
# 11     (10, 15]            0.170538             0.098602
# 12     (15, 20]            0.318315             0.323596
# 13     (15, 20]            0.034459             0.108918
# 14     (10, 15]            0.111992             0.000000
# 15     (10, 15]            0.167760             0.119822
# 16       (0, 5]            0.065858             0.010525

# %% [markdown]
# #### SKLearn Pipeline, FeatureUnion, ColumnTransformer
# * `Pipeline`: chaining estimators
# * `FeatureUnion`: composite feature spaces
# * `ColumnTransformer` for heterogeneous data
# * `TransformedTargetRegressor`: transforming target in regression

# %%
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer, TransformedTargetRegressor
from sklearn.preprocessing import (
    OneHotEncoder, StandardScaler, QuantileTransformer, MinMaxScaler
)
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import SelectKBest, VarianceThreshold
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import set_config

numeric_preprocessor = Pipeline(
    steps=[
        ('quasi_constant_remover', VarianceThreshold(threshold=0.0)),
        (
            "imputation_mean",
            SimpleImputer(missing_values=np.nan, strategy="mean")
        ),
        ("scaler", StandardScaler()),
    ]
)

categorical_preprocessor = Pipeline(
    steps=[
        (
            "imputation_constant", 
            SimpleImputer(fill_value="missing", strategy="constant"),
        ),
        ("onehot", OneHotEncoder(handle_unknown="ignore")),
    ]
)

# Text preprocessing
#------------------------------------------------------------------------------
from sklearn.base import BaseEstimator, TransformerMixin

class AverageWordLengthExtractor(BaseEstimator, TransformerMixin):
    """Takes in dataframe, outputs average word length"""

    def __init__(self):
        pass

    def average_word_length(self, name):
        """Helper code to compute average word length of a name"""
        return np.mean([len(word) for word in name.split()])

    def transform(self, df, y=None):
        """The workhorse of this feature extractor"""
        return df['road_name'].apply(self.average_word_length)

    def fit(self, df, y=None):
        """Returns `self` unless something different happens in train, test"""
        return self

best_word_selector = Pipeline(
    steps=[
        ('bow', CountVectorizer()),
        ('select_one', SelectKBest(k=1))
    ]
)

text_preprocessor = FeatureUnion(
    transformer_list=[
        ('best_word', best_word_selector),
        ('ave', AverageWordLengthExtractor())
    ]
)

preprocessor = ColumnTransformer(
    [
        ('keys', 'drop', ['cif', 'mastercif', 'acct_num']),
        ("categorical", categorical_preprocessor, ["state", "gender"]),
        ("numerical", numeric_preprocessor, ["age", "weight"]),
        ('text', text_preprocessor, ['feedback']),
    ]
)

qt_transformer = QuantileTransformer(output_distribution='normal')
linreg = LinearRegression(n_jobs=-1)
regr = TransformedTargetRegressor(
    regressor=linreg,
    transformer=qt_transformer)

clf = GBMClassifier()

pipe = make_pipeline(preprocessor, clf)

# %%
set_config(display="diagram")
pipe  # click on the diagram below to see the details of each step
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('keys', 'drop',
#                                                   ['cif', 'mastercif',
#                                                    'acct_num']),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('imputation_constant',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['state', 'gender']),
#                                                  ('numerical',
#                                                   Pipeline(steps=[('quasi_constant_remov...
#                                                   ['age', 'weight']),
#                                                  ('text',
#                                                   FeatureUnion(transformer_list=[('best_word',
#                                                                                   Pipeline(steps=[('bow',
#                                                                                                    CountVectorizer()),
#                                                                                                   ('select_one',
#                                                                                                    SelectKBest(k=1))])),
#                                                                                  ('ave',
#                                                                                   AverageWordLengthExtractor())]),
#                                                   ['feedback'])])),
#                 ('transformedtargetregressor',
#                  TransformedTargetRegressor(regressor=LinearRegression(n_jobs=-1),
#                                             transformer=QuantileTransformer(output_distribution='normal')))])

# %%
pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('columntransformer',
#    ColumnTransformer(transformers=[('keys', 'drop',
#                                     ['cif', 'mastercif', 'acct_num']),
#                                    ('categorical',
#                                     Pipeline(steps=[('imputation_constant',
#                                                      SimpleImputer(fill_value='missing',
#                                                                    strategy='constant')),
#                                                     ('onehot',
#                                                      OneHotEncoder(handle_unknown='ignore'))]),
#                                     ['state', 'gender']),
#                                    ('numerical',
#                                     Pipeline(steps=[('quasi_constant_remover',
#                                                      VarianceThreshold()),
#                                                     ('imputation_mean',
#                                                      SimpleImputer()),
#                                                     ('scaler', StandardScaler())]),
#                                     ['age', 'weight']),
#                                    ('text',
#                                     FeatureUnion(transformer_list=[('ngram',
#                                                                     Pipeline(steps=[('bow',
#                                                                                      CountVectorizer()),
#                                                                                     ('select_one',
#                                                                                      SelectKBest(k=1))])),
#                                                                    ('ave',
#                                                                     AverageWordLengthExtractor())]),
#                                     ['feedback'])])),
#   ('transformedtargetregressor',
#    TransformedTargetRegressor(regressor=LinearRegression(n_jobs=-1),
#                               transformer=QuantileTransformer(output_distribution='normal')))],
#  'verbose': False,
#  'columntransformer': ColumnTransformer(transformers=[('keys', 'drop',
#                                   ['cif', 'mastercif', 'acct_num']),
#                                  ('categorical',
#                                   Pipeline(steps=[('imputation_constant',
#                                                    SimpleImputer(fill_value='missing',
#                                                                  strategy='constant')),
#                                                   ('onehot',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   ['state', 'gender']),
#                                  ('numerical',
#                                   Pipeline(steps=[('quasi_constant_remover',
#                                                    VarianceThreshold()),
#                                                   ('imputation_mean',
#                                                    SimpleImputer()),
#                                                   ('scaler', StandardScaler())]),
#                                   ['age', 'weight']),
#                                  ('text',
#                                   FeatureUnion(transformer_list=[('ngram',
#                                                                   Pipeline(steps=[('bow',
#                                                                                    CountVectorizer()),
#                                                                                   ('select_one',
#                                                                                    SelectKBest(k=1))])),
#                                                                  ('ave',
#                                                                   AverageWordLengthExtractor())]),
#                                   ['feedback'])]),
#  'transformedtargetregressor': TransformedTargetRegressor(regressor=LinearRegression(n_jobs=-1),
#                             transformer=QuantileTransformer(output_distribution='normal')),
#  'columntransformer__n_jobs': None,
#  'columntransformer__remainder': 'drop',
#  'columntransformer__sparse_threshold': 0.3,
#  'columntransformer__transformer_weights': None,
#  'columntransformer__transformers': [('keys',
#    'drop',
#    ['cif', 'mastercif', 'acct_num']),
#   ('categorical',
#    Pipeline(steps=[('imputation_constant',
#                     SimpleImputer(fill_value='missing', strategy='constant')),
#                    ('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#    ['state', 'gender']),
#   ('numerical',
#    Pipeline(steps=[('quasi_constant_remover', VarianceThreshold()),
#                    ('imputation_mean', SimpleImputer()),
#                    ('scaler', StandardScaler())]),
#    ['age', 'weight']),
#   ('text',
#    FeatureUnion(transformer_list=[('ngram',
#                                    Pipeline(steps=[('bow', CountVectorizer()),
#                                                    ('select_one',
#                                                     SelectKBest(k=1))])),
#                                   ('ave', AverageWordLengthExtractor())]),
#    ['feedback'])],
#  'columntransformer__verbose': False,
#  'columntransformer__keys': 'drop',
#  'columntransformer__categorical': Pipeline(steps=[('imputation_constant',
#                   SimpleImputer(fill_value='missing', strategy='constant')),
#                  ('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#  'columntransformer__numerical': Pipeline(steps=[('quasi_constant_remover', VarianceThreshold()),
#                  ('imputation_mean', SimpleImputer()),
#                  ('scaler', StandardScaler())]),
#  'columntransformer__text': FeatureUnion(transformer_list=[('ngram',
#                                  Pipeline(steps=[('bow', CountVectorizer()),
#                                                  ('select_one',
#                                                   SelectKBest(k=1))])),
#                                 ('ave', AverageWordLengthExtractor())]),
#  'columntransformer__categorical__memory': None,
#  'columntransformer__categorical__steps': [('imputation_constant',
#    SimpleImputer(fill_value='missing', strategy='constant')),
#   ('onehot', OneHotEncoder(handle_unknown='ignore'))],
#  'columntransformer__categorical__verbose': False,
#  'columntransformer__categorical__imputation_constant': SimpleImputer(fill_value='missing', strategy='constant'),
#  'columntransformer__categorical__onehot': OneHotEncoder(handle_unknown='ignore'),
#  'columntransformer__categorical__imputation_constant__add_indicator': False,
#  'columntransformer__categorical__imputation_constant__copy': True,
#  'columntransformer__categorical__imputation_constant__fill_value': 'missing',
#  'columntransformer__categorical__imputation_constant__missing_values': nan,
#  'columntransformer__categorical__imputation_constant__strategy': 'constant',
#  'columntransformer__categorical__imputation_constant__verbose': 0,
#  'columntransformer__categorical__onehot__categories': 'auto',
#  'columntransformer__categorical__onehot__drop': None,
#  'columntransformer__categorical__onehot__dtype': numpy.float64,
#  'columntransformer__categorical__onehot__handle_unknown': 'ignore',
#  'columntransformer__categorical__onehot__sparse': True,
#  'columntransformer__numerical__memory': None,
#  'columntransformer__numerical__steps': [('quasi_constant_remover',
#    VarianceThreshold()),
#   ('imputation_mean', SimpleImputer()),
#   ('scaler', StandardScaler())],
#  'columntransformer__numerical__verbose': False,
#  'columntransformer__numerical__quasi_constant_remover': VarianceThreshold(),
#  'columntransformer__numerical__imputation_mean': SimpleImputer(),
#  'columntransformer__numerical__scaler': StandardScaler(),
#  'columntransformer__numerical__quasi_constant_remover__threshold': 0.0,
#  'columntransformer__numerical__imputation_mean__add_indicator': False,
#  'columntransformer__numerical__imputation_mean__copy': True,
#  'columntransformer__numerical__imputation_mean__fill_value': None,
#  'columntransformer__numerical__imputation_mean__missing_values': nan,
#  'columntransformer__numerical__imputation_mean__strategy': 'mean',
#  'columntransformer__numerical__imputation_mean__verbose': 0,
#  'columntransformer__numerical__scaler__copy': True,
#  'columntransformer__numerical__scaler__with_mean': True,
#  'columntransformer__numerical__scaler__with_std': True,
#  'columntransformer__text__n_jobs': None,
#  'columntransformer__text__transformer_list': [('ngram',
#    Pipeline(steps=[('bow', CountVectorizer()), ('select_one', SelectKBest(k=1))])),
#   ('ave', AverageWordLengthExtractor())],
#  'columntransformer__text__transformer_weights': None,
#  'columntransformer__text__verbose': False,
#  'columntransformer__text__ngram': Pipeline(steps=[('bow', CountVectorizer()), ('select_one', SelectKBest(k=1))]),
#  'columntransformer__text__ave': AverageWordLengthExtractor(),
#  'columntransformer__text__ngram__memory': None,
#  'columntransformer__text__ngram__steps': [('bow', CountVectorizer()),
#   ('select_one', SelectKBest(k=1))],
#  'columntransformer__text__ngram__verbose': False,
#  'columntransformer__text__ngram__bow': CountVectorizer(),
#  'columntransformer__text__ngram__select_one': SelectKBest(k=1),
#  'columntransformer__text__ngram__bow__analyzer': 'word',
#  'columntransformer__text__ngram__bow__binary': False,
#  'columntransformer__text__ngram__bow__decode_error': 'strict',
#  'columntransformer__text__ngram__bow__dtype': numpy.int64,
#  'columntransformer__text__ngram__bow__encoding': 'utf-8',
#  'columntransformer__text__ngram__bow__input': 'content',
#  'columntransformer__text__ngram__bow__lowercase': True,
#  'columntransformer__text__ngram__bow__max_df': 1.0,
#  'columntransformer__text__ngram__bow__max_features': None,
#  'columntransformer__text__ngram__bow__min_df': 1,
#  'columntransformer__text__ngram__bow__ngram_range': (1, 1),
#  'columntransformer__text__ngram__bow__preprocessor': None,
#  'columntransformer__text__ngram__bow__stop_words': None,
#  'columntransformer__text__ngram__bow__strip_accents': None,
#  'columntransformer__text__ngram__bow__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'columntransformer__text__ngram__bow__tokenizer': None,
#  'columntransformer__text__ngram__bow__vocabulary': None,
#  'columntransformer__text__ngram__select_one__k': 1,
#  'columntransformer__text__ngram__select_one__score_func': <function sklearn.feature_selection._univariate_selection.f_classif(X, y)>,
#  'transformedtargetregressor__check_inverse': True,
#  'transformedtargetregressor__func': None,
#  'transformedtargetregressor__inverse_func': None,
#  'transformedtargetregressor__regressor__copy_X': True,
#  'transformedtargetregressor__regressor__fit_intercept': True,
#  'transformedtargetregressor__regressor__n_jobs': -1,
#  'transformedtargetregressor__regressor__normalize': False,
#  'transformedtargetregressor__regressor__positive': False,
#  'transformedtargetregressor__regressor': LinearRegression(n_jobs=-1),
#  'transformedtargetregressor__transformer__copy': True,
#  'transformedtargetregressor__transformer__ignore_implicit_zeros': False,
#  'transformedtargetregressor__transformer__n_quantiles': 1000,
#  'transformedtargetregressor__transformer__output_distribution': 'normal',
#  'transformedtargetregressor__transformer__random_state': None,
#  'transformedtargetregressor__transformer__subsample': 100000,
#  'transformedtargetregressor__transformer': QuantileTransformer(output_distribution='normal')}

# %% [markdown]
# ### Advantages of Pipelines

# %% [markdown]
# #### Avoid target leakage

# %%
df.loc[lambda x: x.isna().any(axis=1), :]
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 7     2019-03-22 12:47:13  2019-03-22 12:58:17           0       1.4   8.5
# 42    2019-03-30 23:59:14  2019-03-30 23:59:17           1       0.0  80.0
# 445   2019-03-19 06:57:14  2019-03-19 07:00:08           1       1.3   5.5
# 491   2019-03-07 07:11:33  2019-03-07 07:11:39           1       1.6   2.5
# 545   2019-03-27 11:03:43  2019-03-27 11:14:34           1       4.2  15.0
# ...                   ...                  ...         ...       ...   ...
# 6118  2019-03-30 00:49:48  2019-03-30 00:49:56           1       0.0  25.0
# 6169  2019-03-27 02:11:01  2019-03-27 02:12:03           1       4.1   3.0
# 6311  2019-03-12 07:10:30  2019-03-12 07:14:18           1       0.7   4.5
# 6314  2019-03-28 22:36:04  2019-03-28 22:36:07           1       0.0  25.0
# 6356  2019-03-01 16:58:23  2019-03-01 16:58:23           1       0.0   3.0
#
#         tip  tolls   total   color      payment  \
# 7      0.00    0.0   11.80  yellow          NaN
# 42    20.08    0.0  100.38  yellow  credit card
# 445    0.00    0.0    6.30  yellow          NaN
# 491    0.00    0.0    5.80  yellow          NaN
# 545    0.00    0.0   15.80  yellow          NaN
# ...     ...    ...     ...     ...          ...
# 6118   0.00    0.0   25.50   green  credit card
# 6169   0.00    0.0    4.30   green          NaN
# 6311   0.00    0.0    5.30   green          NaN
# 6314   0.00    0.0   25.00   green         cash
# 6356   0.00    0.0    4.80   green         cash
#
#                          pickup_zone                    dropoff_zone  \
# 7                        Murray Hill                        Flatiron
# 42                               NaN                             NaN
# 445                      Boerum Hill                 Columbia Street
# 491                      Murray Hill                     Murray Hill
# 545                LaGuardia Airport                    Forest Hills
# ...                              ...                             ...
# 6118                Prospect Heights                             NaN
# 6169                 Jackson Heights                 Jackson Heights
# 6311  Long Island City/Hunters Point  Long Island City/Hunters Point
# 6314                         Jamaica                             NaN
# 6356              Stuyvesant Heights                             NaN
#
#      pickup_borough dropoff_borough
# 7         Manhattan       Manhattan
# 42              NaN             NaN
# 445        Brooklyn        Brooklyn
# 491       Manhattan       Manhattan
# 545          Queens          Queens
# ...             ...             ...
# 6118       Brooklyn             NaN
# 6169         Queens          Queens
# 6311         Queens          Queens
# 6314         Queens             NaN
# 6356       Brooklyn             NaN
#
# [92 rows x 14 columns]

# %%
df.fillna(df.mode().iloc[0])\
  .loc[df.isna().any(axis=1), :]
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 7     2019-03-22 12:47:13  2019-03-22 12:58:17           0       1.4   8.5
# 42    2019-03-30 23:59:14  2019-03-30 23:59:17           1       0.0  80.0
# 445   2019-03-19 06:57:14  2019-03-19 07:00:08           1       1.3   5.5
# 491   2019-03-07 07:11:33  2019-03-07 07:11:39           1       1.6   2.5
# 545   2019-03-27 11:03:43  2019-03-27 11:14:34           1       4.2  15.0
# ...                   ...                  ...         ...       ...   ...
# 6118  2019-03-30 00:49:48  2019-03-30 00:49:56           1       0.0  25.0
# 6169  2019-03-27 02:11:01  2019-03-27 02:12:03           1       4.1   3.0
# 6311  2019-03-12 07:10:30  2019-03-12 07:14:18           1       0.7   4.5
# 6314  2019-03-28 22:36:04  2019-03-28 22:36:07           1       0.0  25.0
# 6356  2019-03-01 16:58:23  2019-03-01 16:58:23           1       0.0   3.0
#
#         tip  tolls   total   color      payment  \
# 7      0.00    0.0   11.80  yellow  credit card
# 42    20.08    0.0  100.38  yellow  credit card
# 445    0.00    0.0    6.30  yellow  credit card
# 491    0.00    0.0    5.80  yellow  credit card
# 545    0.00    0.0   15.80  yellow  credit card
# ...     ...    ...     ...     ...          ...
# 6118   0.00    0.0   25.50   green  credit card
# 6169   0.00    0.0    4.30   green  credit card
# 6311   0.00    0.0    5.30   green  credit card
# 6314   0.00    0.0   25.00   green         cash
# 6356   0.00    0.0    4.80   green         cash
#
#                          pickup_zone                    dropoff_zone  \
# 7                        Murray Hill                        Flatiron
# 42                    Midtown Center           Upper East Side North
# 445                      Boerum Hill                 Columbia Street
# 491                      Murray Hill                     Murray Hill
# 545                LaGuardia Airport                    Forest Hills
# ...                              ...                             ...
# 6118                Prospect Heights           Upper East Side North
# 6169                 Jackson Heights                 Jackson Heights
# 6311  Long Island City/Hunters Point  Long Island City/Hunters Point
# 6314                         Jamaica           Upper East Side North
# 6356              Stuyvesant Heights           Upper East Side North
#
#      pickup_borough dropoff_borough
# 7         Manhattan       Manhattan
# 42        Manhattan       Manhattan
# 445        Brooklyn        Brooklyn
# 491       Manhattan       Manhattan
# 545          Queens          Queens
# ...             ...             ...
# 6118       Brooklyn       Manhattan
# 6169         Queens          Queens
# 6311         Queens          Queens
# 6314         Queens       Manhattan
# 6356       Brooklyn       Manhattan
#
# [92 rows x 14 columns]

# %%
df.fillna(df.iloc[:4000].mode().iloc[0])\
  .loc[df.isna().any(axis=1), :]
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 7     2019-03-22 12:47:13  2019-03-22 12:58:17           0       1.4   8.5
# 42    2019-03-30 23:59:14  2019-03-30 23:59:17           1       0.0  80.0
# 445   2019-03-19 06:57:14  2019-03-19 07:00:08           1       1.3   5.5
# 491   2019-03-07 07:11:33  2019-03-07 07:11:39           1       1.6   2.5
# 545   2019-03-27 11:03:43  2019-03-27 11:14:34           1       4.2  15.0
# ...                   ...                  ...         ...       ...   ...
# 6118  2019-03-30 00:49:48  2019-03-30 00:49:56           1       0.0  25.0
# 6169  2019-03-27 02:11:01  2019-03-27 02:12:03           1       4.1   3.0
# 6311  2019-03-12 07:10:30  2019-03-12 07:14:18           1       0.7   4.5
# 6314  2019-03-28 22:36:04  2019-03-28 22:36:07           1       0.0  25.0
# 6356  2019-03-01 16:58:23  2019-03-01 16:58:23           1       0.0   3.0
#
#         tip  tolls   total   color      payment  \
# 7      0.00    0.0   11.80  yellow  credit card
# 42    20.08    0.0  100.38  yellow  credit card
# 445    0.00    0.0    6.30  yellow  credit card
# 491    0.00    0.0    5.80  yellow  credit card
# 545    0.00    0.0   15.80  yellow  credit card
# ...     ...    ...     ...     ...          ...
# 6118   0.00    0.0   25.50   green  credit card
# 6169   0.00    0.0    4.30   green  credit card
# 6311   0.00    0.0    5.30   green  credit card
# 6314   0.00    0.0   25.00   green         cash
# 6356   0.00    0.0    4.80   green         cash
#
#                          pickup_zone                    dropoff_zone  \
# 7                        Murray Hill                        Flatiron
# 42                    Midtown Center                  Midtown Center
# 445                      Boerum Hill                 Columbia Street
# 491                      Murray Hill                     Murray Hill
# 545                LaGuardia Airport                    Forest Hills
# ...                              ...                             ...
# 6118                Prospect Heights                  Midtown Center
# 6169                 Jackson Heights                 Jackson Heights
# 6311  Long Island City/Hunters Point  Long Island City/Hunters Point
# 6314                         Jamaica                  Midtown Center
# 6356              Stuyvesant Heights                  Midtown Center
#
#      pickup_borough dropoff_borough
# 7         Manhattan       Manhattan
# 42        Manhattan       Manhattan
# 445        Brooklyn        Brooklyn
# 491       Manhattan       Manhattan
# 545          Queens          Queens
# ...             ...             ...
# 6118       Brooklyn       Manhattan
# 6169         Queens          Queens
# 6311         Queens          Queens
# 6314         Queens       Manhattan
# 6356       Brooklyn       Manhattan
#
# [92 rows x 14 columns]

# %% [markdown]
# #### Grid Search and cross-validation with pipelines is more efficient

# %%
from sklearn.model_selection import GridSearchCV
gs = GridSearchCV(
    estimator=pipe,
    param_grid={
        'text__ngram__ngram__ngram_range': [(1, 1), (1, 2), (1, 3)],
        'text__ave__ave_word_length': [1, 2, 3],
        'regr__regressor__alpha': [0.1, 0.01, 0.001],
        'regr__regressor__max_iter': [100, 1000, 10000],
        'regr__regressor__normalize': [True, False],
        'regr__regressor__fit_intercept': [True, False],
        'columntransformer__numerical__scaler':[
            MinMaxScaler(), StandardScaler(), None, 
        ]
    },
)
gs
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('keys',
#                                                                          'drop',
#                                                                          ['cif',
#                                                                           'mastercif',
#                                                                           'acct_num']),
#                                                                         ('categorical',
#                                                                          Pipeline(steps=[('imputation_constant',
#                                                                                           SimpleImputer(fill_value='missing',
#                                                                                                         strategy='constant')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['state',
#                                                                           'gender']),
#                                                                         ('numerical',
#                                                                          Pipeline(steps=...
#                                         TransformedTargetRegressor(regressor=LinearRegression(n_jobs=-1),
#                                                                    transformer=QuantileTransformer(output_distribution='normal')))]),
#              param_grid={'regr__regressor__alpha': [0.1, 0.01, 0.001],
#                          'regr__regressor__fit_intercept': [True, False],
#                          'regr__regressor__max_iter': [100, 1000, 10000],
#                          'regr__regressor__normalize': [True, False],
#                          'text__ave__ave_word_length': [1, 2, 3],
#                          'text__ngram__ngram__ngram_range': [(1, 1), (1, 2),
#                                                              (1, 3)]})

# %% [markdown]
# # References
# * [6.1. Pipelines and composite estimators](https://scikit-learn.org/stable/modules/compose.html)
